# %% [markdown]
# # DATA CLEANING

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
# Load the Uber dataset
df=pd.read_csv("UberDataset.csv")
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
# Displaying Data structure with its column name and data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# # DATA PREPROCESSING

# %%
# Convert data type of the START_DATE and END_DATE to datetime format
df['START_DATE'] = pd.to_datetime(df['START_DATE'], errors='coerce')
df['END_DATE'] = pd.to_datetime(df['END_DATE'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[ns]
#  1   END_DATE    420 non-null    datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
# Handling missing values
# Drop rows with any missing values
df = df.dropna()

# %%
df
# Out:
#              START_DATE            END_DATE  CATEGORY            START  \
# 0   2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 1   2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 2   2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 3   2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 4   2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# ..                  ...                 ...       ...              ...
# 256 2016-12-12 13:22:00 2016-12-12 13:32:00  Business             Cary
# 257 2016-12-12 13:36:00 2016-12-12 13:51:00  Business             Cary
# 258 2016-12-12 14:26:00 2016-12-12 14:39:00  Business             Apex
# 259 2016-12-12 17:51:00 2016-12-12 18:01:00  Business             Cary
# 260 2016-12-12 20:48:00 2016-12-12 20:57:00  Business      Morrisville
#
#                 STOP  MILES          PURPOSE
# 0        Fort Pierce    5.1   Meal/Entertain
# ...

# %%
#Validate date range
# Ensure that START_DATE is earlier than END_DATE
invalid_dates = df[df['START_DATE'] > df['END_DATE']]
print("\nRows with invalid date ranges (START_DATE > END_DATE):")
print(invalid_dates)
# Out:
# Rows with invalid date ranges (START_DATE > END_DATE):
# Empty DataFrame
# Columns: [START_DATE, END_DATE, CATEGORY, START, STOP, MILES, PURPOSE]
# Index: []

# %%
# Drop rows with invalid date ranges
df = df[df['START_DATE'] <= df['END_DATE']]

# Drop rows with invalid datetime values
df = df.dropna(subset=['START_DATE', 'END_DATE'])

# %%
# Remove rows where MILES is zero or negative
df = df[df['MILES'] > 0]

# %%
# Handling Outliers in MILES
# Identify outliers in the MILES column using the IQR method
q1 = df['MILES'].quantile(0.25)
q3 = df['MILES'].quantile(0.75)
iqr = q3 - q1

# Define acceptable range
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Filter out outliers
df = df[(df['MILES'] >= lower_bound) & (df['MILES'] <= upper_bound)]
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY            START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 1 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 2 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# 5 2016-01-06 17:30:00 2016-01-06 17:35:00  Business  West Palm Beach
#
#               STOP  MILES          PURPOSE
# 0      Fort Pierce    5.1   Meal/Entertain
# 1      Fort Pierce    4.8  Errand/Supplies
# 2      Fort Pierce    4.7          Meeting
# 4  West Palm Beach    4.3   Meal/Entertain
# 5       Palm Beach    7.1          Meeting

# %%
# Reset the index after cleaning
df = df.reset_index(drop=True)
df
# Out:
#              START_DATE            END_DATE  CATEGORY            START  \
# 0   2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 1   2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 2   2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 3   2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# 4   2016-01-06 17:30:00 2016-01-06 17:35:00  Business  West Palm Beach
# ..                  ...                 ...       ...              ...
# 242 2016-12-12 13:22:00 2016-12-12 13:32:00  Business             Cary
# 243 2016-12-12 13:36:00 2016-12-12 13:51:00  Business             Cary
# 244 2016-12-12 14:26:00 2016-12-12 14:39:00  Business             Apex
# 245 2016-12-12 17:51:00 2016-12-12 18:01:00  Business             Cary
# 246 2016-12-12 20:48:00 2016-12-12 20:57:00  Business      Morrisville
#
#                 STOP  MILES          PURPOSE
# 0        Fort Pierce    5.1   Meal/Entertain
# ...

# %%
# Reset the index after cleaning
df = df.reset_index(drop=True)

# %%
# Remove leading and trailing spaces from all string columns
df['CATEGORY'] = df['CATEGORY'].str.strip()
df['PURPOSE'] = df['PURPOSE'].str.strip()

# Convert text to title case (e.g., 'business' -> 'Business')
df['CATEGORY'] = df['CATEGORY'].str.title()
df['PURPOSE'] = df['PURPOSE'].str.title()
df.head(10)
# Out:
#            START_DATE            END_DATE  CATEGORY            START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 1 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 2 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 3 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# 4 2016-01-06 17:30:00 2016-01-06 17:35:00  Business  West Palm Beach
# 5 2016-01-07 13:27:00 2016-01-07 13:33:00  Business             Cary
# 6 2016-01-10 08:05:00 2016-01-10 08:25:00  Business             Cary
# 7 2016-01-10 12:17:00 2016-01-10 12:44:00  Business          Jamaica
# 8 2016-01-10 15:08:00 2016-01-10 15:51:00  Business         New York
# 9 2016-01-10 18:18:00 2016-01-10 18:53:00  Business         Elmhurst
#
#               STOP  MILES          PURPOSE
# 0      Fort Pierce    5.1   Meal/Entertain
# 1      Fort Pierce    4.8  Errand/Supplies
# 2      Fort Pierce    4.7          Meeting
# ...

# %%
# Check for duplicate rows after all cleaning
print("\nFinal check for duplicate rows:")
df.duplicated().sum()
# Out:
# Final check for duplicate rows:
# np.int64(0)

# %%
# Re-check for missing values
print("\nFinal check for missing values:")
df.isnull().sum()
# Out:
# Final check for missing values:
# START_DATE    0
# END_DATE      0
# CATEGORY      0
# START         0
# STOP          0
# MILES         0
# PURPOSE       0
# dtype: int64

# %%
# Check cleaned dataset summary
print("Cleaned Dataset Summary:")
df.info()
# Out:
# Cleaned Dataset Summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  247 non-null    datetime64[ns]
#  1   END_DATE    247 non-null    datetime64[ns]
#  2   CATEGORY    247 non-null    object
#  3   START       247 non-null    object
#  4   STOP        247 non-null    object
#  5   MILES       247 non-null    float64
#  6   PURPOSE     247 non-null    object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 13.6+ KB
